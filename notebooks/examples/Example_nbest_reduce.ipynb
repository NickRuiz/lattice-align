# %%
import fst

# %% [markdown]
# This is sweet. Run these.

# %%
sigma = fst.SymbolTable()
a = fst.linear_chain("hello world".split(), sigma)

# %%
a
# Out:
# <StdVectorFst with 3 states>

# %%
b = fst.linear_chain("hello wilker".split(), sigma)

# %%
b
# Out:
# <StdVectorFst with 3 states>

# %%
c = a.union(b)
c
# Out:
# <StdVectorFst with 6 states>

# %%
c.remove_epsilon()
c
# Out:
# <StdVectorFst with 5 states>

# %%
d = c.determinize()
d
# Out:
# <StdVectorFst with 4 states>

# %%
d.minimize()
d
# Out:
# <StdVectorFst with 3 states>
